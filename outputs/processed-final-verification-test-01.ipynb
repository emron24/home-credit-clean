# %%
# Set default values for papermill to overwrite
handoff_id = "default_id"
artifact_path = "default_path"

# %%
# Parameters
handoff_id = "final-verification-test-01"
artifact_path = "https://github.com/PRODUCER/REPO/releases/latest/artifact.zip"

# %%
# Final smoke test
print(f"Handoff ID: {handoff_id}")
# Out:
# Handoff ID: final-verification-test-01
